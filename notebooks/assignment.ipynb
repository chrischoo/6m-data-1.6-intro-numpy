# %%
import numpy as np  
array_1d = np.arange(10, 20)
print(array_1d)
print('Shape:' + array_1d.shape + '\n')
print('NDimensions:' + array_1d.ndim + '\n')
print('Data Type:' + array_1d.dtype + '\n')
